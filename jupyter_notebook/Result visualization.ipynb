# %%
import pandas as pd
import os
import json
from termcolor import colored

# %%
file_list = ['abalone', 'heart', 'tic-tac-toe']
missingness_flag = [0, 10, 20, 30, 40, 50]  
clf_list = ['DecisionTreeClassifier', 'KNeighborsClassifier', 'RandomForestClassifier', 'XGBClassifier']
imputation_list = ['KNNImputer', 'MICE', 'SimpleImputer_mean', 'GINN', 'GAIN']

# %%
result_path = "C:\\Users\\DELL\\Desktop\\Research\\Study\\Imputation_Surveys\\result\\"

# %%
def txt_extraction(path):
    txt_file = open(path, "r")
    txt = txt_file.read()
    #Covert string to dictionary
    result_dict = json.loads(txt)
    return result_dict['mean']

# %%
def result_extraction(file_name_path, imputation_list, missingness, clf, method):
#     data_missing = {'DecisionTreeClassifier':[],
#                     'KNeighborsClassifier':[],
#                     'RandomForestClassifier':[],
#                     'XGBClassifier':[]
#                    }
    results = []
    for imp_algo in imputation_list:
        clf_folder_path = os.path.join(file_name_path, '{}/data_missing_{}'.format(imp_algo, missingness))
        result_path = os.path.join(clf_folder_path, clf)
        rs_path = os.path.join(result_path, '{}.txt'.format(method))
        result = txt_extraction(rs_path)
        results.append(result)
    return results

# %%
from IPython.core import display as ICD

# %%
def visualization_data(file_name, missingness):
    print('File name: {} - missingness: {}'.format(file_name, missingness))
    file_name_path = os.path.join(result_path, file_name)
    data_missing = {'DecisionTreeClassifier':None,
                    'KNeighborsClassifier':None,
                    'RandomForestClassifier':None,
                    'XGBClassifier':None
                   }
    for clf in clf_list:
        results = result_extraction(file_name_path, imputation_list, missingness, clf, 'accuracy')
        data_missing['{}'.format(clf)] = pd.Series(results, index = imputation_list)
    return data_missing

# %% [markdown]
# ### abalone - Accuracy

# %%
data = visualization_data('abalone', 0)
df = pd.DataFrame(data)
df
# Out:
# File name: abalone - missingness: 0
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.496890              0.525154
# MICE                              0.493295              0.525154
# SimpleImputer_mean                0.496769              0.525154
# GINN                              0.497966              0.525154
# GAIN                              0.495213              0.525154
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.547795       0.542762
# MICE                              0.551270       0.542762
# SimpleImputer_mean                0.548633       0.542762
# GINN                              0.548396       0.542762
# GAIN                              0.545401       0.542762

# %%
data = visualization_data('abalone', 10)
df = pd.DataFrame(data)
df
# Out:
# File name: abalone - missingness: 10
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.484785              0.524555
# MICE                              0.492214              0.526832
# SimpleImputer_mean                0.485621              0.522161
# GINN                              0.497485              0.519766
# GAIN                              0.486226              0.520242
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.545159       0.527310
# MICE                              0.543962       0.538450
# SimpleImputer_mean                0.539412       0.531024
# GINN                              0.552469       0.537613
# GAIN                              0.547197       0.531864

# %%
data = visualization_data('abalone', 20)
df = pd.DataFrame(data)
df
# Out:
# File name: abalone - missingness: 20
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.480956              0.514014
# MICE                              0.475204              0.517129
# SimpleImputer_mean                0.482152              0.512096
# GINN                              0.483230              0.509942
# GAIN                              0.480356              0.510296
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.534019       0.520962
# MICE                              0.541687       0.530425
# SimpleImputer_mean                0.534978       0.522284
# GINN                              0.555344       0.526593
# GAIN                              0.547554       0.525750

# %%
data = visualization_data('abalone', 30)
df = pd.DataFrame(data)
df
# Out:
# File name: abalone - missingness: 30
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.471371              0.508142
# MICE                              0.471249              0.505149
# SimpleImputer_mean                0.462746              0.506466
# GINN                              0.467172              0.495088
# GAIN                              0.482515              0.515092
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.535697       0.520963
# MICE                              0.532702       0.524076
# SimpleImputer_mean                0.530667       0.514853
# GINN                              0.535579       0.506111
# GAIN                              0.549239       0.537263

# %%
data = visualization_data('abalone', 40)
df = pd.DataFrame(data)
df
# Out:
# File name: abalone - missingness: 40
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.472686              0.507428
# MICE                              0.486460              0.518331
# SimpleImputer_mean                0.479513              0.505511
# GINN                              0.478088              0.499525
# GAIN                              0.490291              0.512460
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.526828       0.516170
# MICE                              0.539767       0.523843
# SimpleImputer_mean                0.526833       0.512459
# GINN                              0.555595       0.534750
# GAIN                              0.556540       0.532344

# %%
data = visualization_data('abalone', 50)
df = pd.DataFrame(data)
df
# Out:
# File name: abalone - missingness: 50
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.466223              0.506952
# MICE                              0.480237              0.507187
# SimpleImputer_mean                0.463705              0.503116
# GINN                              0.484069              0.506843
# GAIN                              0.462863              0.502510
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.524680       0.506351
# MICE                              0.529110       0.514620
# SimpleImputer_mean                0.515337       0.507909
# GINN                              0.555464       0.512586
# GAIN                              0.554988       0.527787

# %% [markdown]
# ### heart - Accuracy

# %%
data = visualization_data('heart', 0)
df = pd.DataFrame(data)
df
# Out:
# File name: heart - missingness: 0
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.750000              0.646296
# MICE                              0.737037              0.646296
# SimpleImputer_mean                0.746296              0.646296
# GINN                              0.746296              0.646296
# GAIN                              0.751852              0.646296
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.835185       0.805556
# MICE                              0.824074       0.805556
# SimpleImputer_mean                0.833333       0.805556
# GINN                              0.829630       0.805556
# GAIN                              0.833333       0.809259

# %%
data = visualization_data('heart', 10)
df = pd.DataFrame(data)
df
# Out:
# File name: heart - missingness: 10
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.725926              0.637037
# MICE                              0.738889              0.662963
# SimpleImputer_mean                0.724074              0.638889
# GINN                              0.738889              0.633333
# GAIN                              0.742593              0.642593
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.816667       0.801852
# MICE                              0.822222       0.825926
# SimpleImputer_mean                0.818519       0.816667
# GINN                              0.805556       0.811111
# GAIN                              0.825926       0.820370

# %%
data = visualization_data('heart', 20)
df = pd.DataFrame(data)
df
# Out:
# File name: heart - missingness: 20
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.722222              0.640741
# MICE                              0.731481              0.657407
# SimpleImputer_mean                0.718519              0.633333
# GINN                              0.720370              0.633333
# GAIN                              0.727778              0.646296
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.794444       0.770370
# MICE                              0.835185       0.811111
# SimpleImputer_mean                0.805556       0.779630
# GINN                              0.811111       0.788889
# GAIN                              0.792593       0.783333

# %%
data = visualization_data('heart', 30)
df = pd.DataFrame(data)
df
# Out:
# File name: heart - missingness: 30
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.711111              0.635185
# MICE                              0.759259              0.683333
# SimpleImputer_mean                0.690741              0.620370
# GINN                              0.688889              0.618519
# GAIN                              0.738889              0.653704
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.809259       0.775926
# MICE                              0.846296       0.837037
# SimpleImputer_mean                0.792593       0.787037
# GINN                              0.798148       0.779630
# GAIN                              0.818519       0.811111

# %%
data = visualization_data('heart', 40)
df = pd.DataFrame(data)
df
# Out:
# File name: heart - missingness: 40
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.674074              0.625926
# MICE                              0.764815              0.692593
# SimpleImputer_mean                0.701852              0.612963
# GINN                              0.661111              0.609259
# GAIN                              0.737037              0.637037
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.750000       0.740741
# MICE                              0.833333       0.824074
# SimpleImputer_mean                0.772222       0.768519
# GINN                              0.792593       0.785185
# GAIN                              0.822222       0.812963

# %%
data = visualization_data('heart', 50)
df = pd.DataFrame(data)
df
# Out:
# File name: heart - missingness: 50
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.687037              0.598148
# MICE                              0.775926              0.722222
# SimpleImputer_mean                0.668519              0.629630
# GINN                              0.694444              0.646296
# GAIN                              0.727778              0.624074
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.735185       0.755556
# MICE                              0.846296       0.842593
# SimpleImputer_mean                0.740741       0.725926
# GINN                              0.768519       0.744444
# GAIN                              0.829630       0.816667

# %% [markdown]
# ### tic-tac-toe - Accuracy

# %%
data = visualization_data('tic-tac-toe', 0)
df = pd.DataFrame(data)
df
# Out:
# File name: tic-tac-toe - missingness: 0
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.881002              0.766192
# MICE                              0.875810              0.766192
# SimpleImputer_mean                0.882592              0.766192
# GINN                              0.882581              0.766192
# GAIN                              0.879442              0.766192
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.935289       0.998432
# MICE                              0.935818       0.998432
# SimpleImputer_mean                0.933745       0.998432
# GINN                              0.933745       0.998432
# GAIN                              0.934255       0.998432

# %%
data = visualization_data('tic-tac-toe', 10)
df = pd.DataFrame(data)
df
# Out:
# File name: tic-tac-toe - missingness: 10
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.858554              0.762530
# MICE                              0.874220              0.766192
# SimpleImputer_mean                0.875783              0.764602
# GINN                              0.853330              0.756250
# GAIN                              0.827203              0.756771
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.899801       0.959288
# MICE                              0.923298       0.981204
# SimpleImputer_mean                0.911807       0.969723
# GINN                              0.900314       0.954044
# GAIN                              0.888321       0.950924

# %%
data = visualization_data('tic-tac-toe', 20)
df = pd.DataFrame(data)
df
# Out:
# File name: tic-tac-toe - missingness: 20
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.823552              0.750534
# MICE                              0.875777              0.776628
# SimpleImputer_mean                0.844955              0.754726
# GINN                              0.818903              0.743224
# GAIN                              0.815246              0.753657
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.870593       0.921196
# MICE                              0.924343       0.964512
# SimpleImputer_mean                0.890437       0.939452
# GINN                              0.882605       0.924343
# GAIN                              0.870073       0.912306

# %%
data = visualization_data('tic-tac-toe', 30)
df = pd.DataFrame(data)
df
# Out:
# File name: tic-tac-toe - missingness: 30
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.795427              0.728621
# MICE                              0.844489              0.772478
# SimpleImputer_mean                0.801145              0.742703
# GINN                              0.810062              0.741154
# GAIN                              0.770850              0.742708
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.838752       0.879456
# MICE                              0.899853       0.933751
# SimpleImputer_mean                0.848683       0.902394
# GINN                              0.854428       0.884680
# GAIN                              0.841356       0.875777

# %%
data = visualization_data('tic-tac-toe', 40)
df = pd.DataFrame(data)
df
# Out:
# File name: tic-tac-toe - missingness: 40
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.761499              0.703539
# MICE                              0.829925              0.750532
# SimpleImputer_mean                0.784443              0.702509
# GINN                              0.769865              0.721818
# GAIN                              0.785496              0.753629
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.791260       0.832973
# MICE                              0.880511       0.899845
# SimpleImputer_mean                0.828294       0.869006
# GINN                              0.827291       0.858584
# GAIN                              0.821002       0.854388

# %%
data = visualization_data('tic-tac-toe', 50)
df = pd.DataFrame(data)
df
# Out:
# File name: tic-tac-toe - missingness: 50
#                     DecisionTreeClassifier  KNeighborsClassifier  \
# KNNImputer                        0.723874              0.704606
# MICE                              0.815246              0.752094
# SimpleImputer_mean                0.744233              0.696736
# GINN                              0.754123              0.735351
# GAIN                              0.752656              0.743194
#
#                     RandomForestClassifier  XGBClassifier
# KNNImputer                        0.781315       0.809495
# MICE                              0.866920       0.902457
# SimpleImputer_mean                0.799591       0.837688
# GINN                              0.800055       0.832924
# GAIN                              0.802708       0.810005
